# %%
import math
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import f1_score

import mne
from scipy import linalg
from mne.decoding import CSP
from scipy.signal import butter, filtfilt

# %%
class EEGDataset(Dataset):
    base_path = 'mtcaic3'
    label_encoding = {'Left': 0, 'Right': 1}

    # Sensitivity values (replace with your device's actual values if different)
    gyro_scale  = 0.02  # deg/s per LSB
    gyro_offset = 0
    acc_scale   = 0.000598  # g per LSB
    acc_offset  = 0

    def __init__(self, csv_path, task=None, segment_length=250, overlap=0.5):
        self.metadata = pd.read_csv(csv_path)
        self.task = task

        if self.task:
            self.metadata = self.metadata[self.metadata['task'] == self.task]

    def __len__(self):
        return len(self.metadata)

    def _butter_bandpass(self, lowcut=8.0, highcut=30.0, fs=250, order=4):
        nyq = 0.5 * fs
        low = lowcut / nyq
        high = highcut / nyq
        b, a = butter(order, [low, high], btype='band')
        return b, a

    def _bandpass_filter(self, data, lowcut=8, highcut=30, fs=250, order=5):
        b, a = self._butter_bandpass(lowcut, highcut, fs, order=order)
        y = filtfilt(b, a, data, axis=0)
        return y

    def _spatial_filtering(self, eeg_values):
        return eeg_values  # placeholder for Laplacian if needed

    def _car_reference(self, eeg_values, cz_idx, pz_idx):
        car_ref = (eeg_values[cz_idx] + eeg_values[pz_idx]) / 2
        eeg_values = eeg_values - car_ref
        return eeg_values

    def _normalize(self, data):
        mean = np.mean(data, axis=1, keepdims=True)
        std = np.std(data, axis=1, keepdims=True)
        return (data - mean) / std

    def _convert_gyro(self, gyro_values):
        # gyro_values: (3, n_samples)
        return (gyro_values - self.gyro_offset) * self.gyro_scale  # deg/s

    def _convert_acc(self, acc_values):
        # acc_values: (3, n_samples)
        return (acc_values - self.acc_offset) * self.acc_scale  # g

    def _get_eeg_data(self, row):
        id_num = row['id']
        if id_num <= 4800:
            dataset = 'train'
        elif id_num <= 4900:
            dataset = 'validation'
        else:
            dataset = 'test'

        eeg_path = f"{self.base_path}/{row['task']}/{dataset}/{row['subject_id']}/{row['trial_session']}/EEGdata.csv"
        eeg_data = pd.read_csv(eeg_path)
        trial_num = int(row['trial'])

        samples_per_trial = 2250 if row['task'] == 'MI' else 1750
        start_idx = (trial_num - 1) * samples_per_trial
        end_idx = start_idx + samples_per_trial - 1
        eeg_data = eeg_data.iloc[start_idx:end_idx + 1]
        return eeg_data

    def __getitem__(self, idx):
        row = self.metadata.iloc[idx]
        eeg_data = self._get_eeg_data(row)

        # EEG channels
        selected_channels = ['C3', 'CZ', 'C4', 'PZ']
        eeg_values = eeg_data[selected_channels].values.astype(np.float32).T  # (4, n_samples)
        eeg_values = self._bandpass_filter(eeg_values.T).T  # (4, n_samples)
        eeg_values = self._spatial_filtering(eeg_values)

        # CAR referencing using CZ and PZ, then remove them
        cz_idx = selected_channels.index('CZ')
        pz_idx = selected_channels.index('PZ')
        eeg_values = self._car_reference(eeg_values, cz_idx, pz_idx)
        keep_indices = [selected_channels.index('C3'), selected_channels.index('C4')]
        eeg_values = eeg_values[keep_indices, :]  # (2, n_samples)

        # Normalize EEG
        eeg_values = self._normalize(eeg_values)

        # Segment selection (from 2nd to 6th)
        fs = 250
        start_sample = int(2 * fs)
        end_sample = int(6 * fs)
        eeg_values = eeg_values[:, start_sample:end_sample]  # (2, 1000)
        eeg_tensor = torch.from_numpy(eeg_values.astype(np.float32)).transpose(0, 1)  # (1000, 2)

        # Motion channels
        acc_channels = ['AccX', 'AccY', 'AccZ']
        gyro_channels = ['Gyro1', 'Gyro2', 'Gyro3']
        acc_values = eeg_data[acc_channels].values.astype(np.float32).T  # (3, n_samples)
        gyro_values = eeg_data[gyro_channels].values.astype(np.float32).T  # (3, n_samples)

        # Convert to physical units
        #acc_values = self._convert_acc(acc_values)
        gyro_values = self._convert_gyro(gyro_values)

        # Normalize motion data (optional, can comment out if not needed)
        #acc_values = self._normalize(acc_values)
        #gyro_values = self._normalize(gyro_values)

        # Segment selection for motion
        acc_values = acc_values[:, start_sample:end_sample]    # (3, 750)
        gyro_values = gyro_values[:, start_sample:end_sample]  # (3, 750)

        # Combine motion data
        motion_values = np.concatenate([acc_values, gyro_values], axis=0)  # (6, 750)
        motion_tensor = torch.from_numpy(motion_values.astype(np.float32)).transpose(0, 1)  # (750, 6)

        label_tensor = torch.tensor(self.label_encoding[row['label']], dtype=torch.long)

        return eeg_tensor, motion_tensor, label_tensor

# %%
class MotionAwareDenoiser(nn.Module):
    """ICA-inspired denoiser with motion artifact removal"""
    def __init__(self, eeg_channels=7, motion_channels=6, hidden_dim=64):
        super().__init__()
        
        # EEG processing branch
        self.eeg_projection = nn.Sequential(
            nn.Conv1d(eeg_channels, hidden_dim, kernel_size=1),
            nn.BatchNorm1d(hidden_dim),
            nn.ELU()
        )
        
        # Motion processing branch
        self.motion_projection = nn.Sequential(
            nn.Conv1d(motion_channels, hidden_dim, kernel_size=1),
            nn.BatchNorm1d(hidden_dim),
            nn.ELU()
        )
        
        # Temporal feature extraction
        self.temporal_conv = nn.Sequential(
            nn.Conv1d(hidden_dim*2, hidden_dim*2, kernel_size=15, padding=7, groups=2),
            nn.BatchNorm1d(hidden_dim*2),
            nn.ELU(),
            nn.Conv1d(hidden_dim*2, hidden_dim*2, kernel_size=15, padding=7, groups=2),
            nn.BatchNorm1d(hidden_dim*2),
            nn.ELU()
        )
        
        # Attention mechanism to focus on motion artifacts
        self.attention = nn.Sequential(
            nn.Conv1d(hidden_dim*2, hidden_dim, kernel_size=1),
            nn.BatchNorm1d(hidden_dim),
            nn.ELU(),
            nn.Conv1d(hidden_dim, 1, kernel_size=1),
            nn.Sigmoid()
        )
        
        # Reconstruction to EEG space
        self.reconstruction = nn.Sequential(
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1),
            nn.BatchNorm1d(hidden_dim),
            nn.ELU(),
            nn.Conv1d(hidden_dim, eeg_channels, kernel_size=1)
        )

    def forward(self, eeg, motion):
        # Project both signals to common space
        eeg_features = self.eeg_projection(eeg)
        motion_features = self.motion_projection(motion)
        
        # Concatenate features
        combined = torch.cat([eeg_features, motion_features], dim=1)
        
        # Extract temporal features
        temporal_features = self.temporal_conv(combined)
        
        # Attention mask for artifact regions
        attention_mask = self.attention(temporal_features)
        
        # Apply attention to EEG features
        attended_eeg = eeg_features * (1 - attention_mask)
        
        # Reconstruct clean EEG
        clean_eeg = self.reconstruction(attended_eeg)
        
        return clean_eeg

class SpatialAttentionClassifier(nn.Module):
    """Classifier with spatial attention"""
    def __init__(self, input_channels=7, num_classes=4, seq_length=500):
        super().__init__()
        
        # Spatial attention
        self.spatial_attention = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),
            nn.Conv1d(input_channels, input_channels//2, 1),
            nn.ELU(),
            nn.Conv1d(input_channels//2, input_channels, 1),
            nn.Sigmoid()
        )
        
        # Temporal feature extraction
        self.temporal_features = nn.Sequential(
            nn.Conv1d(input_channels, 64, kernel_size=25, padding=12),
            nn.BatchNorm1d(64),
            nn.ELU(),
            nn.MaxPool1d(4),
            
            nn.Conv1d(64, 128, kernel_size=15, padding=7),
            nn.BatchNorm1d(128),
            nn.ELU(),
            nn.MaxPool1d(4),
            
            nn.Conv1d(128, 256, kernel_size=15, padding=7),
            nn.BatchNorm1d(256),
            nn.ELU(),
            nn.AdaptiveAvgPool1d(1)
        )
        
        # Classification head
        self.classifier = nn.Sequential(
            nn.Linear(256, 128),
            nn.ELU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # Apply spatial attention
        spatial_weights = self.spatial_attention(x)
        x_attended = x * spatial_weights
        
        # Extract temporal features
        features = self.temporal_features(x_attended)
        features = features.squeeze(-1)
        
        # Classify
        return self.classifier(features)

class EEGPipeline(nn.Module):
    """Simplified end-to-end pipeline"""
    def __init__(self, eeg_channels=7, motion_channels=6, num_classes=4):
        super().__init__()
        
        self.denoiser = MotionAwareDenoiser(eeg_channels, motion_channels)
        self.classifier = SpatialAttentionClassifier(eeg_channels, num_classes)
        
        # Normalization layers
        self.eeg_norm = nn.BatchNorm1d(eeg_channels)
        self.motion_norm = nn.BatchNorm1d(motion_channels)
        
    def forward(self, eeg, motion):
        # Normalize inputs
        eeg = self.eeg_norm(eeg)
        motion = self.motion_norm(motion)
        
        # Denoise EEG using motion information
        clean_eeg = self.denoiser(eeg, motion)
        
        # Classification
        logits = self.classifier(clean_eeg)
        
        return logits

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize dataset and dataloader
dataset = EEGDataset("mtcaic3/train.csv", task='MI')
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

val_dataset = EEGDataset("mtcaic3/validation.csv", task='MI')
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
model  = EEGPipeline(eeg_channels=2, motion_channels=6, num_classes=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# %%
print(f"trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
# Out:
# trainable parameters: 912412

# %%
# check loader
for data in dataloader:
    print(data[0].shape, data[1].shape, data[2].shape)
    break
# Out:
# torch.Size([32, 1000, 2]) torch.Size([32, 1000, 6]) torch.Size([32])

# %%
best_f1         = 0
best_loss       = float('inf')
num_epochs      = 100
patience        = 15                   # Number of epochs to wait before early stopping
epochs_without_improvement = 0  # Counter for epochs without improvement

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_predictions = []
    train_targets = []
    
    for i, (eeg_values, motion_values, labels) in enumerate(dataloader):
        # Permute dimensions to match model input expectations
        eeg_values = eeg_values.permute(0, 2, 1).to(device)  # [batch, channels, time]
        motion_values = motion_values.permute(0, 2, 1).to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(eeg_values, motion_values)
        loss    = criterion(outputs, labels)  # Using EEGLoss which returns tuple
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        
        # Store predictions and targets for F1 calculation
        train_predictions.extend(predicted.cpu().numpy())
        train_targets.extend(labels.cpu().numpy())
        
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i}/{len(dataloader)}], Loss: {loss.item():.4f}')

    # Validation
    model.eval()
    all_preds = []
    all_labels = []
    val_loss = 0.0
    val_predictions = []
    val_targets = []
    
    with torch.no_grad():
        for eeg_val, motion_val, labels_val in val_dataloader:
            eeg_val = eeg_val.permute(0, 2, 1).to(device)
            motion_val = motion_val.permute(0, 2, 1).to(device)
            labels_val = labels_val.to(device)
            
            outputs = model(eeg_val, motion_val)
            loss    = criterion(outputs, labels_val)
            
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            
            # Store predictions and targets for F1 calculation
            val_predictions.extend(predicted.cpu().numpy())
            val_targets.extend(labels_val.cpu().numpy())
    
    # Calculate metrics
    train_acc = 100. * sum([p == t for p, t in zip(train_predictions, train_targets)]) / len(train_targets)
    val_acc = 100. * sum([p == t for p, t in zip(val_predictions, val_targets)]) / len(val_targets)
    
    # Calculate F1-scores (macro and weighted)
    train_f1 = f1_score(train_targets, train_predictions, average='macro')*100
    
    val_f1 = f1_score(val_targets, val_predictions, average='macro')*100
    
    prev_lr = optimizer.param_groups[0]['lr']
    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    print("=" * 100)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train - Loss: {train_loss/len(dataloader):.4f}, Acc: {train_acc:.2f}%, F1(macro): {train_f1:.2f}%, Current LR: {current_lr:.6f}')
    print(f'Epoch [{epoch+1}/{num_epochs}], Val   - Loss: {val_loss/len(val_dataloader):.4f}, Acc: {val_acc:.2f}%, F1(macro): {val_f1:.2f}%, Current LR: {current_lr:.6f}')
    print("=" * 100)

    # Check for improvement
    if (val_f1 > best_f1) or (val_loss < best_loss):
        if (val_f1 > best_f1):
            best_f1   = val_f1
        else:
            best_loss = val_loss
            
        epochs_without_improvement = 0  # Reset counter
        
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': best_loss,
            'f1': best_f1,
        }, f'weights/MI/mi_model_{epoch+1}.pth')
        
    else:
        epochs_without_improvement += 1
        print(f"No improvement in validation for {epochs_without_improvement} epochs, Best Val F1 is {best_f1}")
        
        # # Early stopping check
        # if epochs_without_improvement >= patience:
        #     print(f"Early stopping triggered after {patience} epochs without improvement")
        #     break
# Out:
# Epoch [1/100], Step [0/75], Loss: 0.7311
# Epoch [1/100], Step [10/75], Loss: 0.7394
# Epoch [1/100], Step [20/75], Loss: 0.7310
# Epoch [1/100], Step [30/75], Loss: 0.7543
# Epoch [1/100], Step [40/75], Loss: 0.6878
# Epoch [1/100], Step [50/75], Loss: 0.6746
# Epoch [1/100], Step [60/75], Loss: 0.7256
# Epoch [1/100], Step [70/75], Loss: 0.6878
# ====================================================================================================
# Epoch [1/100], Train - Loss: 0.7214, Acc: 49.67%, F1(macro): 49.64%, Current LR: 0.001000
# Epoch [1/100], Val   - Loss: 0.6930, Acc: 54.00%, F1(macro): 35.06%, Current LR: 0.001000
# ====================================================================================================
# Epoch [2/100], Step [0/75], Loss: 0.7160
# Epoch [2/100], Step [10/75], Loss: 0.6891
# Epoch [2/100], Step [20/75], Loss: 0.6857
# Epoch [2/100], Step [30/75], Loss: 0.7005
# Epoch [2/100], Step [40/75], Loss: 0.7442
# Epoch [2/100], Step [50/75], Loss: 0.7566
# Epoch [2/100], Step [60/75], Loss: 0.6920
# Epoch [2/100], Step [70/75], Loss: 0.7005
# ====================================================================================================
# Epoch [2/100], Train - Loss: 0.7039, Acc: 50.12%, F1(macro): 50.11%, Current LR: 0.000999
# Epoch [2/100], Val   - Loss: 0.7160, Acc: 44.00%, F1(macro): 39.24%, Current LR: 0.000999
# ====================================================================================================
# Epoch [3/100], Step [0/75], Loss: 0.7352
# Epoch [3/100], Step [10/75], Loss: 0.7092
# Epoch [3/100], Step [20/75], Loss: 0.6991
# Epoch [3/100], Step [30/75], Loss: 0.7116
# Epoch [3/100], Step [40/75], Loss: 0.7103
# Epoch [3/100], Step [50/75], Loss: 0.7232
# Epoch [3/100], Step [60/75], Loss: 0.6810
# Epoch [3/100], Step [70/75], Loss: 0.6924
# ====================================================================================================
# Epoch [3/100], Train - Loss: 0.7002, Acc: 50.50%, F1(macro): 50.40%, Current LR: 0.000998
# Epoch [3/100], Val   - Loss: 0.7541, Acc: 44.00%, F1(macro): 43.18%, Current LR: 0.000998
# ====================================================================================================
# Epoch [4/100], Step [0/75], Loss: 0.6450
# Epoch [4/100], Step [10/75], Loss: 0.6936
# Epoch [4/100], Step [20/75], Loss: 0.6887
# Epoch [4/100], Step [30/75], Loss: 0.6953
# Epoch [4/100], Step [40/75], Loss: 0.7401
# Epoch [4/100], Step [50/75], Loss: 0.7194
# Epoch [4/100], Step [60/75], Loss: 0.6787
# Epoch [4/100], Step [70/75], Loss: 0.6977
# ====================================================================================================
# Epoch [4/100], Train - Loss: 0.7012, Acc: 50.38%, F1(macro): 50.16%, Current LR: 0.000996
# Epoch [4/100], Val   - Loss: 0.7002, Acc: 50.00%, F1(macro): 49.82%, Current LR: 0.000996
# ====================================================================================================
# Epoch [5/100], Step [0/75], Loss: 0.7367
# Epoch [5/100], Step [10/75], Loss: 0.7056
# Epoch [5/100], Step [20/75], Loss: 0.6900
# Epoch [5/100], Step [30/75], Loss: 0.7009
# Epoch [5/100], Step [40/75], Loss: 0.7099
# Epoch [5/100], Step [50/75], Loss: 0.7382
# Epoch [5/100], Step [60/75], Loss: 0.6846
# Epoch [5/100], Step [70/75], Loss: 0.6852
# ====================================================================================================
# Epoch [5/100], Train - Loss: 0.6965, Acc: 50.12%, F1(macro): 49.83%, Current LR: 0.000994
# Epoch [5/100], Val   - Loss: 0.7018, Acc: 48.00%, F1(macro): 47.92%, Current LR: 0.000994
# ====================================================================================================
# Epoch [6/100], Step [0/75], Loss: 0.6800
# Epoch [6/100], Step [10/75], Loss: 0.7141
# Epoch [6/100], Step [20/75], Loss: 0.7198
# Epoch [6/100], Step [30/75], Loss: 0.6934
# Epoch [6/100], Step [40/75], Loss: 0.7019
# Epoch [6/100], Step [50/75], Loss: 0.7090
# Epoch [6/100], Step [60/75], Loss: 0.6851
# Epoch [6/100], Step [70/75], Loss: 0.6993
# ====================================================================================================
# Epoch [6/100], Train - Loss: 0.6947, Acc: 52.25%, F1(macro): 52.19%, Current LR: 0.000991
# Epoch [6/100], Val   - Loss: 0.6954, Acc: 44.00%, F1(macro): 43.18%, Current LR: 0.000991
# ====================================================================================================
# Epoch [7/100], Step [0/75], Loss: 0.6843
# Epoch [7/100], Step [10/75], Loss: 0.6944
# Epoch [7/100], Step [20/75], Loss: 0.6821
# Epoch [7/100], Step [30/75], Loss: 0.6902
# Epoch [7/100], Step [40/75], Loss: 0.6950
# Epoch [7/100], Step [50/75], Loss: 0.6779
# Epoch [7/100], Step [60/75], Loss: 0.7019
# Epoch [7/100], Step [70/75], Loss: 0.6727
# ====================================================================================================
# Epoch [7/100], Train - Loss: 0.6951, Acc: 52.25%, F1(macro): 51.75%, Current LR: 0.000988
# Epoch [7/100], Val   - Loss: 0.7005, Acc: 38.00%, F1(macro): 35.92%, Current LR: 0.000988
# ====================================================================================================
# No improvement in validation for 1 epochs, Best Val F1 is 49.81934965877158
# Epoch [8/100], Step [0/75], Loss: 0.6948
# Epoch [8/100], Step [10/75], Loss: 0.6595
# Epoch [8/100], Step [20/75], Loss: 0.6954
# Epoch [8/100], Step [30/75], Loss: 0.6968
# Epoch [8/100], Step [40/75], Loss: 0.6922
# Epoch [8/100], Step [50/75], Loss: 0.6931
# Epoch [8/100], Step [60/75], Loss: 0.6876
# Epoch [8/100], Step [70/75], Loss: 0.6889
# ====================================================================================================
# Epoch [8/100], Train - Loss: 0.6949, Acc: 52.33%, F1(macro): 51.55%, Current LR: 0.000984
# Epoch [8/100], Val   - Loss: 0.7024, Acc: 42.00%, F1(macro): 41.98%, Current LR: 0.000984
# ====================================================================================================
# No improvement in validation for 2 epochs, Best Val F1 is 49.81934965877158
# Epoch [9/100], Step [0/75], Loss: 0.6893
# Epoch [9/100], Step [10/75], Loss: 0.6692
# Epoch [9/100], Step [20/75], Loss: 0.6976
# Epoch [9/100], Step [30/75], Loss: 0.7044
# Epoch [9/100], Step [40/75], Loss: 0.7009
# Epoch [9/100], Step [50/75], Loss: 0.6925
# Epoch [9/100], Step [60/75], Loss: 0.6845
# Epoch [9/100], Step [70/75], Loss: 0.7005
# ====================================================================================================
# Epoch [9/100], Train - Loss: 0.6950, Acc: 51.00%, F1(macro): 50.92%, Current LR: 0.000980
# Epoch [9/100], Val   - Loss: 0.6930, Acc: 54.00%, F1(macro): 53.98%, Current LR: 0.000980
# ====================================================================================================
# Epoch [10/100], Step [0/75], Loss: 0.6989
# Epoch [10/100], Step [10/75], Loss: 0.7098
# Epoch [10/100], Step [20/75], Loss: 0.7010
# Epoch [10/100], Step [30/75], Loss: 0.6987
# Epoch [10/100], Step [40/75], Loss: 0.7218
# Epoch [10/100], Step [50/75], Loss: 0.6944
# Epoch [10/100], Step [60/75], Loss: 0.6924
# Epoch [10/100], Step [70/75], Loss: 0.7035
# ====================================================================================================
# Epoch [10/100], Train - Loss: 0.6953, Acc: 51.33%, F1(macro): 51.30%, Current LR: 0.000976
# Epoch [10/100], Val   - Loss: 0.7003, Acc: 42.00%, F1(macro): 40.84%, Current LR: 0.000976
# ====================================================================================================
# No improvement in validation for 1 epochs, Best Val F1 is 53.98159263705482
# Epoch [11/100], Step [0/75], Loss: 0.6858
# Epoch [11/100], Step [10/75], Loss: 0.6734
# Epoch [11/100], Step [20/75], Loss: 0.7092
# Epoch [11/100], Step [30/75], Loss: 0.7212
# Epoch [11/100], Step [40/75], Loss: 0.6964
# Epoch [11/100], Step [50/75], Loss: 0.6893
# Epoch [11/100], Step [60/75], Loss: 0.7031
# Epoch [11/100], Step [70/75], Loss: 0.6934
# ====================================================================================================
# Epoch [11/100], Train - Loss: 0.6936, Acc: 51.71%, F1(macro): 51.00%, Current LR: 0.000970
# Epoch [11/100], Val   - Loss: 0.7016, Acc: 58.00%, F1(macro): 55.86%, Current LR: 0.000970
# ====================================================================================================
# Epoch [12/100], Step [0/75], Loss: 0.6979
# Epoch [12/100], Step [10/75], Loss: 0.6928
# Epoch [12/100], Step [20/75], Loss: 0.6902
# Epoch [12/100], Step [30/75], Loss: 0.6974
# Epoch [12/100], Step [40/75], Loss: 0.7080
# Epoch [12/100], Step [50/75], Loss: 0.7103
# Epoch [12/100], Step [60/75], Loss: 0.6947
# Epoch [12/100], Step [70/75], Loss: 0.6989
# ====================================================================================================
# Epoch [12/100], Train - Loss: 0.6932, Acc: 51.67%, F1(macro): 51.56%, Current LR: 0.000965
# Epoch [12/100], Val   - Loss: 0.7089, Acc: 44.00%, F1(macro): 43.64%, Current LR: 0.000965
# ====================================================================================================
# No improvement in validation for 1 epochs, Best Val F1 is 55.86380832282472
# Epoch [13/100], Step [0/75], Loss: 0.6910
# Epoch [13/100], Step [10/75], Loss: 0.6845
# Epoch [13/100], Step [20/75], Loss: 0.7006
# Epoch [13/100], Step [30/75], Loss: 0.7026
# Epoch [13/100], Step [40/75], Loss: 0.6958
# Epoch [13/100], Step [50/75], Loss: 0.6792
# Epoch [13/100], Step [60/75], Loss: 0.6491
# Epoch [13/100], Step [70/75], Loss: 0.7290
# ====================================================================================================
# Epoch [13/100], Train - Loss: 0.6925, Acc: 52.79%, F1(macro): 52.68%, Current LR: 0.000959
# Epoch [13/100], Val   - Loss: 0.7163, Acc: 52.00%, F1(macro): 51.92%, Current LR: 0.000959
# ====================================================================================================
# No improvement in validation for 2 epochs, Best Val F1 is 55.86380832282472
# Epoch [14/100], Step [0/75], Loss: 0.6678
# Epoch [14/100], Step [10/75], Loss: 0.6940
# Epoch [14/100], Step [20/75], Loss: 0.6928
# Epoch [14/100], Step [30/75], Loss: 0.6824
# Epoch [14/100], Step [40/75], Loss: 0.6621
# Epoch [14/100], Step [50/75], Loss: 0.6840
# Epoch [14/100], Step [60/75], Loss: 0.7002
# Epoch [14/100], Step [70/75], Loss: 0.6813
# ====================================================================================================
# Epoch [14/100], Train - Loss: 0.6926, Acc: 52.75%, F1(macro): 52.25%, Current LR: 0.000952
# Epoch [14/100], Val   - Loss: 0.6956, Acc: 52.00%, F1(macro): 51.92%, Current LR: 0.000952
# ====================================================================================================
# No improvement in validation for 3 epochs, Best Val F1 is 55.86380832282472
# Epoch [15/100], Step [0/75], Loss: 0.6894
# Epoch [15/100], Step [10/75], Loss: 0.7161
# Epoch [15/100], Step [20/75], Loss: 0.6712
# Epoch [15/100], Step [30/75], Loss: 0.6624
# Epoch [15/100], Step [40/75], Loss: 0.6878
# Epoch [15/100], Step [50/75], Loss: 0.6962
# Epoch [15/100], Step [60/75], Loss: 0.6906
# Epoch [15/100], Step [70/75], Loss: 0.6766
# ====================================================================================================
# Epoch [15/100], Train - Loss: 0.6921, Acc: 52.88%, F1(macro): 52.13%, Current LR: 0.000946
# Epoch [15/100], Val   - Loss: 0.7018, Acc: 50.00%, F1(macro): 49.00%, Current LR: 0.000946
# ====================================================================================================
# No improvement in validation for 4 epochs, Best Val F1 is 55.86380832282472
# Epoch [16/100], Step [0/75], Loss: 0.6908
# Epoch [16/100], Step [10/75], Loss: 0.7166
# Epoch [16/100], Step [20/75], Loss: 0.6912
# Epoch [16/100], Step [30/75], Loss: 0.6748
# Epoch [16/100], Step [40/75], Loss: 0.7087
# Epoch [16/100], Step [50/75], Loss: 0.6988
# Epoch [16/100], Step [60/75], Loss: 0.6817
# Epoch [16/100], Step [70/75], Loss: 0.6993
# ====================================================================================================
# Epoch [16/100], Train - Loss: 0.6906, Acc: 53.21%, F1(macro): 53.18%, Current LR: 0.000938
# Epoch [16/100], Val   - Loss: 0.6831, Acc: 52.00%, F1(macro): 47.92%, Current LR: 0.000938
# ====================================================================================================
# Epoch [17/100], Step [0/75], Loss: 0.6876
# Epoch [17/100], Step [10/75], Loss: 0.6666
# Epoch [17/100], Step [20/75], Loss: 0.6907
# Epoch [17/100], Step [30/75], Loss: 0.6984
# Epoch [17/100], Step [40/75], Loss: 0.6932
# Epoch [17/100], Step [50/75], Loss: 0.6960
# Epoch [17/100], Step [60/75], Loss: 0.7132
# Epoch [17/100], Step [70/75], Loss: 0.6674
# ====================================================================================================
# Epoch [17/100], Train - Loss: 0.6915, Acc: 53.62%, F1(macro): 53.42%, Current LR: 0.000930
# Epoch [17/100], Val   - Loss: 0.7106, Acc: 40.00%, F1(macro): 39.12%, Current LR: 0.000930
# ====================================================================================================
# No improvement in validation for 1 epochs, Best Val F1 is 55.86380832282472
# Epoch [18/100], Step [0/75], Loss: 0.6684
# Epoch [18/100], Step [10/75], Loss: 0.7122
# Epoch [18/100], Step [20/75], Loss: 0.6869
# Epoch [18/100], Step [30/75], Loss: 0.6994
# Epoch [18/100], Step [40/75], Loss: 0.6839
# Epoch [18/100], Step [50/75], Loss: 0.6911
# Epoch [18/100], Step [60/75], Loss: 0.6954
# Epoch [18/100], Step [70/75], Loss: 0.6840
# ====================================================================================================
# Epoch [18/100], Train - Loss: 0.6943, Acc: 51.88%, F1(macro): 51.87%, Current LR: 0.000922
# Epoch [18/100], Val   - Loss: 0.6919, Acc: 48.00%, F1(macro): 47.92%, Current LR: 0.000922
# ====================================================================================================
# No improvement in validation for 2 epochs, Best Val F1 is 55.86380832282472
# Epoch [19/100], Step [0/75], Loss: 0.7095
# Epoch [19/100], Step [10/75], Loss: 0.7247
# Epoch [19/100], Step [20/75], Loss: 0.6925
# Epoch [19/100], Step [30/75], Loss: 0.6815
# Epoch [19/100], Step [40/75], Loss: 0.6916
# Epoch [19/100], Step [50/75], Loss: 0.6745
# Epoch [19/100], Step [60/75], Loss: 0.7105
# Epoch [19/100], Step [70/75], Loss: 0.7026
# ====================================================================================================
# Epoch [19/100], Train - Loss: 0.6924, Acc: 52.88%, F1(macro): 52.51%, Current LR: 0.000914
# Epoch [19/100], Val   - Loss: 0.6930, Acc: 50.00%, F1(macro): 49.00%, Current LR: 0.000914
# ====================================================================================================
# No improvement in validation for 3 epochs, Best Val F1 is 55.86380832282472
# Epoch [20/100], Step [0/75], Loss: 0.7458
# Epoch [20/100], Step [10/75], Loss: 0.7109
# Epoch [20/100], Step [20/75], Loss: 0.7024
# Epoch [20/100], Step [30/75], Loss: 0.6781
# Epoch [20/100], Step [40/75], Loss: 0.6956
# Epoch [20/100], Step [50/75], Loss: 0.6170
# Epoch [20/100], Step [60/75], Loss: 0.6436
# Epoch [20/100], Step [70/75], Loss: 0.7084
# ====================================================================================================
# Epoch [20/100], Train - Loss: 0.6899, Acc: 54.29%, F1(macro): 53.94%, Current LR: 0.000905
# Epoch [20/100], Val   - Loss: 0.6984, Acc: 50.00%, F1(macro): 49.98%, Current LR: 0.000905
# ====================================================================================================
# No improvement in validation for 4 epochs, Best Val F1 is 55.86380832282472
# Epoch [21/100], Step [0/75], Loss: 0.6823
# Epoch [21/100], Step [10/75], Loss: 0.6765
# Epoch [21/100], Step [20/75], Loss: 0.7176
# Epoch [21/100], Step [30/75], Loss: 0.6763
# Epoch [21/100], Step [40/75], Loss: 0.6861
# Epoch [21/100], Step [50/75], Loss: 0.6870
# Epoch [21/100], Step [60/75], Loss: 0.6634
# Epoch [21/100], Step [70/75], Loss: 0.7183
# ====================================================================================================
# Epoch [21/100], Train - Loss: 0.6872, Acc: 54.79%, F1(macro): 54.41%, Current LR: 0.000895
# Epoch [21/100], Val   - Loss: 0.7007, Acc: 50.00%, F1(macro): 48.33%, Current LR: 0.000895
# ====================================================================================================
# No improvement in validation for 5 epochs, Best Val F1 is 55.86380832282472
# Epoch [22/100], Step [0/75], Loss: 0.6995
# Epoch [22/100], Step [10/75], Loss: 0.6785
# Epoch [22/100], Step [20/75], Loss: 0.6735
# Epoch [22/100], Step [30/75], Loss: 0.7348
# Epoch [22/100], Step [40/75], Loss: 0.6871
# Epoch [22/100], Step [50/75], Loss: 0.6912
# Epoch [22/100], Step [60/75], Loss: 0.6710
# Epoch [22/100], Step [70/75], Loss: 0.6856
# ====================================================================================================
# Epoch [22/100], Train - Loss: 0.6915, Acc: 52.92%, F1(macro): 52.68%, Current LR: 0.000885
# Epoch [22/100], Val   - Loss: 0.6990, Acc: 54.00%, F1(macro): 53.54%, Current LR: 0.000885
# ====================================================================================================
# No improvement in validation for 6 epochs, Best Val F1 is 55.86380832282472
# Epoch [23/100], Step [0/75], Loss: 0.6803
# Epoch [23/100], Step [10/75], Loss: 0.6759
# Epoch [23/100], Step [20/75], Loss: 0.6968
# Epoch [23/100], Step [30/75], Loss: 0.7376
# Epoch [23/100], Step [40/75], Loss: 0.6778
# Epoch [23/100], Step [50/75], Loss: 0.6893
# Epoch [23/100], Step [60/75], Loss: 0.7093
# Epoch [23/100], Step [70/75], Loss: 0.6955
# ====================================================================================================
# Epoch [23/100], Train - Loss: 0.6903, Acc: 52.58%, F1(macro): 52.26%, Current LR: 0.000875
# Epoch [23/100], Val   - Loss: 0.6982, Acc: 48.00%, F1(macro): 46.63%, Current LR: 0.000875
# ====================================================================================================
# No improvement in validation for 7 epochs, Best Val F1 is 55.86380832282472
# Epoch [24/100], Step [0/75], Loss: 0.6840
# Epoch [24/100], Step [10/75], Loss: 0.6880
# Epoch [24/100], Step [20/75], Loss: 0.6808
# Epoch [24/100], Step [30/75], Loss: 0.6836
# Epoch [24/100], Step [40/75], Loss: 0.6687
# Epoch [24/100], Step [50/75], Loss: 0.8027
# Epoch [24/100], Step [60/75], Loss: 0.7008
# Epoch [24/100], Step [70/75], Loss: 0.6906
# ====================================================================================================
# Epoch [24/100], Train - Loss: 0.6893, Acc: 54.71%, F1(macro): 54.52%, Current LR: 0.000864
# Epoch [24/100], Val   - Loss: 0.7008, Acc: 46.00%, F1(macro): 45.80%, Current LR: 0.000864
# ====================================================================================================
# No improvement in validation for 8 epochs, Best Val F1 is 55.86380832282472
# Epoch [25/100], Step [0/75], Loss: 0.6766
# Epoch [25/100], Step [10/75], Loss: 0.6883
# Epoch [25/100], Step [20/75], Loss: 0.6874
# Epoch [25/100], Step [30/75], Loss: 0.7097
# Epoch [25/100], Step [40/75], Loss: 0.6778
# Epoch [25/100], Step [50/75], Loss: 0.7053
# Epoch [25/100], Step [60/75], Loss: 0.7135
# Epoch [25/100], Step [70/75], Loss: 0.7170
# ====================================================================================================
# Epoch [25/100], Train - Loss: 0.6861, Acc: 54.92%, F1(macro): 54.71%, Current LR: 0.000854
# Epoch [25/100], Val   - Loss: 0.7098, Acc: 44.00%, F1(macro): 41.67%, Current LR: 0.000854
# ====================================================================================================
# No improvement in validation for 9 epochs, Best Val F1 is 55.86380832282472
# Epoch [26/100], Step [0/75], Loss: 0.6881
# Epoch [26/100], Step [10/75], Loss: 0.6742
# Epoch [26/100], Step [20/75], Loss: 0.6792
# Epoch [26/100], Step [30/75], Loss: 0.7008
# Epoch [26/100], Step [40/75], Loss: 0.7263
# Epoch [26/100], Step [50/75], Loss: 0.6928
# Epoch [26/100], Step [60/75], Loss: 0.6796
# Epoch [26/100], Step [70/75], Loss: 0.6856
# ====================================================================================================
# Epoch [26/100], Train - Loss: 0.6876, Acc: 54.17%, F1(macro): 54.05%, Current LR: 0.000842
# Epoch [26/100], Val   - Loss: 0.7212, Acc: 40.00%, F1(macro): 37.50%, Current LR: 0.000842
# ====================================================================================================
# No improvement in validation for 10 epochs, Best Val F1 is 55.86380832282472
# Epoch [27/100], Step [0/75], Loss: 0.7466
# Epoch [27/100], Step [10/75], Loss: 0.7216
# Epoch [27/100], Step [20/75], Loss: 0.7210
# Epoch [27/100], Step [30/75], Loss: 0.6980
# Epoch [27/100], Step [40/75], Loss: 0.6931
# Epoch [27/100], Step [50/75], Loss: 0.7075
# Epoch [27/100], Step [60/75], Loss: 0.6877
# Epoch [27/100], Step [70/75], Loss: 0.6634
# ====================================================================================================
# Epoch [27/100], Train - Loss: 0.6913, Acc: 53.42%, F1(macro): 53.38%, Current LR: 0.000831
# Epoch [27/100], Val   - Loss: 0.6848, Acc: 60.00%, F1(macro): 58.95%, Current LR: 0.000831
# ====================================================================================================
# Epoch [28/100], Step [0/75], Loss: 0.6846
# Epoch [28/100], Step [10/75], Loss: 0.6780
# Epoch [28/100], Step [20/75], Loss: 0.6994
# Epoch [28/100], Step [30/75], Loss: 0.6913
# Epoch [28/100], Step [40/75], Loss: 0.6772
# Epoch [28/100], Step [50/75], Loss: 0.7002
# Epoch [28/100], Step [60/75], Loss: 0.6504
# Epoch [28/100], Step [70/75], Loss: 0.6863
# ====================================================================================================
# Epoch [28/100], Train - Loss: 0.6867, Acc: 54.92%, F1(macro): 53.98%, Current LR: 0.000819
# Epoch [28/100], Val   - Loss: 0.6948, Acc: 50.00%, F1(macro): 49.98%, Current LR: 0.000819
# ====================================================================================================
# No improvement in validation for 1 epochs, Best Val F1 is 58.94909688013137
# Epoch [29/100], Step [0/75], Loss: 0.6726
# Epoch [29/100], Step [10/75], Loss: 0.6873
# Epoch [29/100], Step [20/75], Loss: 0.6757
# Epoch [29/100], Step [30/75], Loss: 0.6677
# Epoch [29/100], Step [40/75], Loss: 0.6859
# Epoch [29/100], Step [50/75], Loss: 0.6916
# Epoch [29/100], Step [60/75], Loss: 0.7050
# Epoch [29/100], Step [70/75], Loss: 0.6707
# ====================================================================================================
# Epoch [29/100], Train - Loss: 0.6868, Acc: 55.67%, F1(macro): 55.60%, Current LR: 0.000806
# Epoch [29/100], Val   - Loss: 0.6977, Acc: 52.00%, F1(macro): 51.92%, Current LR: 0.000806
# ====================================================================================================
# No improvement in validation for 2 epochs, Best Val F1 is 58.94909688013137
# Epoch [30/100], Step [0/75], Loss: 0.6914
# Epoch [30/100], Step [10/75], Loss: 0.7028
# Epoch [30/100], Step [20/75], Loss: 0.6865
# Epoch [30/100], Step [30/75], Loss: 0.7566
# Epoch [30/100], Step [40/75], Loss: 0.7172
# Epoch [30/100], Step [50/75], Loss: 0.6624
# Epoch [30/100], Step [60/75], Loss: 0.7022
# Epoch [30/100], Step [70/75], Loss: 0.6778
# ====================================================================================================
# Epoch [30/100], Train - Loss: 0.6815, Acc: 56.83%, F1(macro): 56.76%, Current LR: 0.000794
# Epoch [30/100], Val   - Loss: 0.7044, Acc: 56.00%, F1(macro): 53.31%, Current LR: 0.000794
# ====================================================================================================
# No improvement in validation for 3 epochs, Best Val F1 is 58.94909688013137
# Epoch [31/100], Step [0/75], Loss: 0.6668
# Epoch [31/100], Step [10/75], Loss: 0.7150
# Epoch [31/100], Step [20/75], Loss: 0.6692
# Epoch [31/100], Step [30/75], Loss: 0.6676
# Epoch [31/100], Step [40/75], Loss: 0.6778
# Epoch [31/100], Step [50/75], Loss: 0.6668
# Epoch [31/100], Step [60/75], Loss: 0.6925
# Epoch [31/100], Step [70/75], Loss: 0.6845
# ====================================================================================================
# Epoch [31/100], Train - Loss: 0.6873, Acc: 54.88%, F1(macro): 54.71%, Current LR: 0.000781
# Epoch [31/100], Val   - Loss: 0.7015, Acc: 44.00%, F1(macro): 41.67%, Current LR: 0.000781
# ====================================================================================================
# No improvement in validation for 4 epochs, Best Val F1 is 58.94909688013137
# Epoch [32/100], Step [0/75], Loss: 0.6908
# Epoch [32/100], Step [10/75], Loss: 0.6831
# Epoch [32/100], Step [20/75], Loss: 0.6989
# Epoch [32/100], Step [30/75], Loss: 0.6707
# Epoch [32/100], Step [40/75], Loss: 0.6964
# Epoch [32/100], Step [50/75], Loss: 0.6896
# Epoch [32/100], Step [60/75], Loss: 0.6500
# Epoch [32/100], Step [70/75], Loss: 0.7004
# ====================================================================================================
# Epoch [32/100], Train - Loss: 0.6825, Acc: 56.96%, F1(macro): 56.82%, Current LR: 0.000768
# Epoch [32/100], Val   - Loss: 0.6890, Acc: 54.00%, F1(macro): 53.08%, Current LR: 0.000768
# ====================================================================================================
# No improvement in validation for 5 epochs, Best Val F1 is 58.94909688013137
# Epoch [33/100], Step [0/75], Loss: 0.8021
# Epoch [33/100], Step [10/75], Loss: 0.6364
# Epoch [33/100], Step [20/75], Loss: 0.6012
# Epoch [33/100], Step [30/75], Loss: 0.6928
# Epoch [33/100], Step [40/75], Loss: 0.6499
# Epoch [33/100], Step [50/75], Loss: 0.7762
# Epoch [33/100], Step [60/75], Loss: 0.6611
# Epoch [33/100], Step [70/75], Loss: 0.6560
# ====================================================================================================
# Epoch [33/100], Train - Loss: 0.6798, Acc: 56.92%, F1(macro): 56.54%, Current LR: 0.000755
# Epoch [33/100], Val   - Loss: 0.6975, Acc: 56.00%, F1(macro): 53.31%, Current LR: 0.000755
# ====================================================================================================
# No improvement in validation for 6 epochs, Best Val F1 is 58.94909688013137
# Epoch [34/100], Step [0/75], Loss: 0.6957
# Epoch [34/100], Step [10/75], Loss: 0.6942
# Epoch [34/100], Step [20/75], Loss: 0.6475
# Epoch [34/100], Step [30/75], Loss: 0.6690
# Epoch [34/100], Step [40/75], Loss: 0.6726
# Epoch [34/100], Step [50/75], Loss: 0.6814
# Epoch [34/100], Step [60/75], Loss: 0.7306
# Epoch [34/100], Step [70/75], Loss: 0.6257
# ====================================================================================================
# Epoch [34/100], Train - Loss: 0.6804, Acc: 55.38%, F1(macro): 54.70%, Current LR: 0.000741
# Epoch [34/100], Val   - Loss: 0.7025, Acc: 56.00%, F1(macro): 49.45%, Current LR: 0.000741
# ====================================================================================================
# No improvement in validation for 7 epochs, Best Val F1 is 58.94909688013137
# Epoch [35/100], Step [0/75], Loss: 0.7123
# Epoch [35/100], Step [10/75], Loss: 0.6999
# Epoch [35/100], Step [20/75], Loss: 0.7036
# Epoch [35/100], Step [30/75], Loss: 0.7117
# Epoch [35/100], Step [40/75], Loss: 0.6760
# Epoch [35/100], Step [50/75], Loss: 0.6773
# Epoch [35/100], Step [60/75], Loss: 0.6432
# Epoch [35/100], Step [70/75], Loss: 0.7219
# ====================================================================================================
# Epoch [35/100], Train - Loss: 0.6795, Acc: 57.29%, F1(macro): 57.25%, Current LR: 0.000727
# Epoch [35/100], Val   - Loss: 0.7427, Acc: 42.00%, F1(macro): 29.58%, Current LR: 0.000727
# ====================================================================================================
# No improvement in validation for 8 epochs, Best Val F1 is 58.94909688013137
# Epoch [36/100], Step [0/75], Loss: 0.6985
# Epoch [36/100], Step [10/75], Loss: 0.6788
# Epoch [36/100], Step [20/75], Loss: 0.6780
# Epoch [36/100], Step [30/75], Loss: 0.6592
# Epoch [36/100], Step [40/75], Loss: 0.7148
# Epoch [36/100], Step [50/75], Loss: 0.6529
# Epoch [36/100], Step [60/75], Loss: 0.7141
# Epoch [36/100], Step [70/75], Loss: 0.6769
# ====================================================================================================
# Epoch [36/100], Train - Loss: 0.6775, Acc: 57.42%, F1(macro): 57.11%, Current LR: 0.000713
# Epoch [36/100], Val   - Loss: 0.7225, Acc: 44.00%, F1(macro): 40.58%, Current LR: 0.000713
# ====================================================================================================
# No improvement in validation for 9 epochs, Best Val F1 is 58.94909688013137
# Epoch [37/100], Step [0/75], Loss: 0.6769
# Epoch [37/100], Step [10/75], Loss: 0.6747
# Epoch [37/100], Step [20/75], Loss: 0.6681
# Epoch [37/100], Step [30/75], Loss: 0.6696
# Epoch [37/100], Step [40/75], Loss: 0.6202
# Epoch [37/100], Step [50/75], Loss: 0.7190
# Epoch [37/100], Step [60/75], Loss: 0.7368
# Epoch [37/100], Step [70/75], Loss: 0.6106
# ====================================================================================================
# Epoch [37/100], Train - Loss: 0.6745, Acc: 57.58%, F1(macro): 57.58%, Current LR: 0.000699
# Epoch [37/100], Val   - Loss: 0.6898, Acc: 56.00%, F1(macro): 50.98%, Current LR: 0.000699
# ====================================================================================================
# No improvement in validation for 10 epochs, Best Val F1 is 58.94909688013137
# Epoch [38/100], Step [0/75], Loss: 0.7145
# Epoch [38/100], Step [10/75], Loss: 0.6734
# Epoch [38/100], Step [20/75], Loss: 0.7047
# Epoch [38/100], Step [30/75], Loss: 0.6774
# Epoch [38/100], Step [40/75], Loss: 0.6423
# Epoch [38/100], Step [50/75], Loss: 0.6195
# Epoch [38/100], Step [60/75], Loss: 0.6689
# Epoch [38/100], Step [70/75], Loss: 0.6592
# ====================================================================================================
# Epoch [38/100], Train - Loss: 0.6744, Acc: 58.33%, F1(macro): 58.17%, Current LR: 0.000684
# Epoch [38/100], Val   - Loss: 0.7115, Acc: 56.00%, F1(macro): 55.72%, Current LR: 0.000684
# ====================================================================================================
# No improvement in validation for 11 epochs, Best Val F1 is 58.94909688013137
# Epoch [39/100], Step [0/75], Loss: 0.6791
# Epoch [39/100], Step [10/75], Loss: 0.6659
# Epoch [39/100], Step [20/75], Loss: 0.6991
# Epoch [39/100], Step [30/75], Loss: 0.7037
# Epoch [39/100], Step [40/75], Loss: 0.6383
# Epoch [39/100], Step [50/75], Loss: 0.6701
# Epoch [39/100], Step [60/75], Loss: 0.6974
# Epoch [39/100], Step [70/75], Loss: 0.5918
# ====================================================================================================
# Epoch [39/100], Train - Loss: 0.6721, Acc: 59.08%, F1(macro): 58.89%, Current LR: 0.000669
# Epoch [39/100], Val   - Loss: 0.8308, Acc: 40.00%, F1(macro): 28.57%, Current LR: 0.000669
# ====================================================================================================
# No improvement in validation for 12 epochs, Best Val F1 is 58.94909688013137
# Epoch [40/100], Step [0/75], Loss: 0.7273
# Epoch [40/100], Step [10/75], Loss: 0.6737
# Epoch [40/100], Step [20/75], Loss: 0.6876
# Epoch [40/100], Step [30/75], Loss: 0.6557
# Epoch [40/100], Step [40/75], Loss: 0.6232
# Epoch [40/100], Step [50/75], Loss: 0.6956
# Epoch [40/100], Step [60/75], Loss: 0.6595
# Epoch [40/100], Step [70/75], Loss: 0.7074
# ====================================================================================================
# Epoch [40/100], Train - Loss: 0.6701, Acc: 58.54%, F1(macro): 58.42%, Current LR: 0.000655
# Epoch [40/100], Val   - Loss: 0.8281, Acc: 42.00%, F1(macro): 29.58%, Current LR: 0.000655
# ====================================================================================================
# No improvement in validation for 13 epochs, Best Val F1 is 58.94909688013137
# Epoch [41/100], Step [0/75], Loss: 0.6647
# Epoch [41/100], Step [10/75], Loss: 0.6394
# Epoch [41/100], Step [20/75], Loss: 0.6950
# Epoch [41/100], Step [30/75], Loss: 0.6339
# Epoch [41/100], Step [40/75], Loss: 0.6593
# Epoch [41/100], Step [50/75], Loss: 0.6925
# Epoch [41/100], Step [60/75], Loss: 0.6450
# Epoch [41/100], Step [70/75], Loss: 0.6359
# ====================================================================================================
# Epoch [41/100], Train - Loss: 0.6679, Acc: 57.96%, F1(macro): 57.82%, Current LR: 0.000639
# Epoch [41/100], Val   - Loss: 0.7092, Acc: 46.00%, F1(macro): 44.92%, Current LR: 0.000639
# ====================================================================================================
# No improvement in validation for 14 epochs, Best Val F1 is 58.94909688013137
# Epoch [42/100], Step [0/75], Loss: 0.6537
# Epoch [42/100], Step [10/75], Loss: 0.7186
# Epoch [42/100], Step [20/75], Loss: 0.6213
# Epoch [42/100], Step [30/75], Loss: 0.6351
# Epoch [42/100], Step [40/75], Loss: 0.5990
# Epoch [42/100], Step [50/75], Loss: 0.6847
# Epoch [42/100], Step [60/75], Loss: 0.6636
# Epoch [42/100], Step [70/75], Loss: 0.6995
# ====================================================================================================
# Epoch [42/100], Train - Loss: 0.6667, Acc: 59.83%, F1(macro): 59.59%, Current LR: 0.000624
# Epoch [42/100], Val   - Loss: 0.6449, Acc: 58.00%, F1(macro): 53.85%, Current LR: 0.000624
# ====================================================================================================
# Epoch [43/100], Step [0/75], Loss: 0.6553
# Epoch [43/100], Step [10/75], Loss: 0.6724
# Epoch [43/100], Step [20/75], Loss: 0.6763
# Epoch [43/100], Step [30/75], Loss: 0.6592
# Epoch [43/100], Step [40/75], Loss: 0.7336
# Epoch [43/100], Step [50/75], Loss: 0.6177
# Epoch [43/100], Step [60/75], Loss: 0.6225
# Epoch [43/100], Step [70/75], Loss: 0.6574
# ====================================================================================================
# Epoch [43/100], Train - Loss: 0.6629, Acc: 61.33%, F1(macro): 61.05%, Current LR: 0.000609
# Epoch [43/100], Val   - Loss: 0.6868, Acc: 52.00%, F1(macro): 50.00%, Current LR: 0.000609
# ====================================================================================================
# No improvement in validation for 1 epochs, Best Val F1 is 58.94909688013137
# Epoch [44/100], Step [0/75], Loss: 0.6616
# Epoch [44/100], Step [10/75], Loss: 0.6877
# Epoch [44/100], Step [20/75], Loss: 0.6743
# Epoch [44/100], Step [30/75], Loss: 0.7222
# Epoch [44/100], Step [40/75], Loss: 0.6262
# Epoch [44/100], Step [50/75], Loss: 0.6302
# Epoch [44/100], Step [60/75], Loss: 0.6240
# Epoch [44/100], Step [70/75], Loss: 0.7222
# ====================================================================================================
# Epoch [44/100], Train - Loss: 0.6596, Acc: 59.42%, F1(macro): 59.24%, Current LR: 0.000594
# Epoch [44/100], Val   - Loss: 0.7371, Acc: 42.00%, F1(macro): 37.79%, Current LR: 0.000594
# ====================================================================================================
# No improvement in validation for 2 epochs, Best Val F1 is 58.94909688013137
# Epoch [45/100], Step [0/75], Loss: 0.6143
# Epoch [45/100], Step [10/75], Loss: 0.7223
# Epoch [45/100], Step [20/75], Loss: 0.5354
# Epoch [45/100], Step [30/75], Loss: 0.6353
# Epoch [45/100], Step [40/75], Loss: 0.6739
# Epoch [45/100], Step [50/75], Loss: 0.6875
# Epoch [45/100], Step [60/75], Loss: 0.6829
# Epoch [45/100], Step [70/75], Loss: 0.6382
# ====================================================================================================
# Epoch [45/100], Train - Loss: 0.6558, Acc: 60.46%, F1(macro): 60.37%, Current LR: 0.000578
# Epoch [45/100], Val   - Loss: 0.7792, Acc: 42.00%, F1(macro): 36.26%, Current LR: 0.000578
# ====================================================================================================
# No improvement in validation for 3 epochs, Best Val F1 is 58.94909688013137
# Epoch [46/100], Step [0/75], Loss: 0.6332
# Epoch [46/100], Step [10/75], Loss: 0.5901
# Epoch [46/100], Step [20/75], Loss: 0.5567
# Epoch [46/100], Step [30/75], Loss: 0.6031
# Epoch [46/100], Step [40/75], Loss: 0.7409
# Epoch [46/100], Step [50/75], Loss: 0.6198
# Epoch [46/100], Step [60/75], Loss: 0.6774
# Epoch [46/100], Step [70/75], Loss: 0.7054
# ====================================================================================================
# Epoch [46/100], Train - Loss: 0.6493, Acc: 61.79%, F1(macro): 61.53%, Current LR: 0.000563
# Epoch [46/100], Val   - Loss: 0.6639, Acc: 56.00%, F1(macro): 55.36%, Current LR: 0.000563
# ====================================================================================================
# No improvement in validation for 4 epochs, Best Val F1 is 58.94909688013137
# Epoch [47/100], Step [0/75], Loss: 0.6047
# Epoch [47/100], Step [10/75], Loss: 0.6751
# Epoch [47/100], Step [20/75], Loss: 0.6361
# Epoch [47/100], Step [30/75], Loss: 0.6420
# Epoch [47/100], Step [40/75], Loss: 0.6573
# Epoch [47/100], Step [50/75], Loss: 0.6583
# Epoch [47/100], Step [60/75], Loss: 0.6552
# Epoch [47/100], Step [70/75], Loss: 0.6889
# ====================================================================================================
# Epoch [47/100], Train - Loss: 0.6396, Acc: 63.25%, F1(macro): 62.97%, Current LR: 0.000547
# Epoch [47/100], Val   - Loss: 0.6962, Acc: 50.00%, F1(macro): 49.98%, Current LR: 0.000547
# ====================================================================================================
# No improvement in validation for 5 epochs, Best Val F1 is 58.94909688013137
# Epoch [48/100], Step [0/75], Loss: 0.6872
# Epoch [48/100], Step [10/75], Loss: 0.5546
# Epoch [48/100], Step [20/75], Loss: 0.6696
# Epoch [48/100], Step [30/75], Loss: 0.6189
# Epoch [48/100], Step [40/75], Loss: 0.6415
# Epoch [48/100], Step [50/75], Loss: 0.6210
# Epoch [48/100], Step [60/75], Loss: 0.6024
# Epoch [48/100], Step [70/75], Loss: 0.5672
# ====================================================================================================
# Epoch [48/100], Train - Loss: 0.6424, Acc: 62.21%, F1(macro): 62.20%, Current LR: 0.000531
# Epoch [48/100], Val   - Loss: 0.7985, Acc: 58.00%, F1(macro): 52.51%, Current LR: 0.000531
# ====================================================================================================
# No improvement in validation for 6 epochs, Best Val F1 is 58.94909688013137
# Epoch [49/100], Step [0/75], Loss: 0.6251
# Epoch [49/100], Step [10/75], Loss: 0.6688
# Epoch [49/100], Step [20/75], Loss: 0.5987
# Epoch [49/100], Step [30/75], Loss: 0.5866
# Epoch [49/100], Step [40/75], Loss: 0.6839
# Epoch [49/100], Step [50/75], Loss: 0.5342
# Epoch [49/100], Step [60/75], Loss: 0.6000
# Epoch [49/100], Step [70/75], Loss: 0.6231
# ====================================================================================================
# Epoch [49/100], Train - Loss: 0.6330, Acc: 64.04%, F1(macro): 63.95%, Current LR: 0.000516
# Epoch [49/100], Val   - Loss: 0.9580, Acc: 44.00%, F1(macro): 33.33%, Current LR: 0.000516
# ====================================================================================================
# No improvement in validation for 7 epochs, Best Val F1 is 58.94909688013137
# Epoch [50/100], Step [0/75], Loss: 0.7332
# Epoch [50/100], Step [10/75], Loss: 0.5288
# Epoch [50/100], Step [20/75], Loss: 0.5696
# Epoch [50/100], Step [30/75], Loss: 0.5104
# Epoch [50/100], Step [40/75], Loss: 0.5278
# Epoch [50/100], Step [50/75], Loss: 0.5574
# Epoch [50/100], Step [60/75], Loss: 0.5706
# Epoch [50/100], Step [70/75], Loss: 0.6803
# ====================================================================================================
# Epoch [50/100], Train - Loss: 0.6143, Acc: 65.46%, F1(macro): 65.31%, Current LR: 0.000500
# Epoch [50/100], Val   - Loss: 0.7037, Acc: 46.00%, F1(macro): 45.45%, Current LR: 0.000500
# ====================================================================================================
# No improvement in validation for 8 epochs, Best Val F1 is 58.94909688013137
# Epoch [51/100], Step [0/75], Loss: 0.7195
# Epoch [51/100], Step [10/75], Loss: 0.6066
# Epoch [51/100], Step [20/75], Loss: 0.5302
# Epoch [51/100], Step [30/75], Loss: 0.6220
# Epoch [51/100], Step [40/75], Loss: 0.7001
# Epoch [51/100], Step [50/75], Loss: 0.5921
# Epoch [51/100], Step [60/75], Loss: 0.5977
# Epoch [51/100], Step [70/75], Loss: 0.6317
# ====================================================================================================
# Epoch [51/100], Train - Loss: 0.6079, Acc: 65.71%, F1(macro): 65.58%, Current LR: 0.000484
# Epoch [51/100], Val   - Loss: 0.7323, Acc: 46.00%, F1(macro): 44.19%, Current LR: 0.000484
# ====================================================================================================
# No improvement in validation for 9 epochs, Best Val F1 is 58.94909688013137
# Epoch [52/100], Step [0/75], Loss: 0.5647
# Epoch [52/100], Step [10/75], Loss: 0.5510
# Epoch [52/100], Step [20/75], Loss: 0.6732
# Epoch [52/100], Step [30/75], Loss: 0.5273
# Epoch [52/100], Step [40/75], Loss: 0.5640
# Epoch [52/100], Step [50/75], Loss: 0.6766
# Epoch [52/100], Step [60/75], Loss: 0.6478
# Epoch [52/100], Step [70/75], Loss: 0.5806
# ====================================================================================================
# Epoch [52/100], Train - Loss: 0.6091, Acc: 65.75%, F1(macro): 65.67%, Current LR: 0.000469
# Epoch [52/100], Val   - Loss: 0.7074, Acc: 54.00%, F1(macro): 53.83%, Current LR: 0.000469
# ====================================================================================================
# No improvement in validation for 10 epochs, Best Val F1 is 58.94909688013137
# Epoch [53/100], Step [0/75], Loss: 0.6167
# Epoch [53/100], Step [10/75], Loss: 0.4733
# Epoch [53/100], Step [20/75], Loss: 0.3982
# Epoch [53/100], Step [30/75], Loss: 0.5287
# Epoch [53/100], Step [40/75], Loss: 0.5608
# Epoch [53/100], Step [50/75], Loss: 0.6628
# Epoch [53/100], Step [60/75], Loss: 0.6214
# Epoch [53/100], Step [70/75], Loss: 0.6953
# ====================================================================================================
# Epoch [53/100], Train - Loss: 0.5899, Acc: 68.08%, F1(macro): 68.03%, Current LR: 0.000453
# Epoch [53/100], Val   - Loss: 0.9075, Acc: 40.00%, F1(macro): 33.16%, Current LR: 0.000453
# ====================================================================================================
# No improvement in validation for 11 epochs, Best Val F1 is 58.94909688013137
# Epoch [54/100], Step [0/75], Loss: 0.5137
# Epoch [54/100], Step [10/75], Loss: 0.6178
# Epoch [54/100], Step [20/75], Loss: 0.5987
# Epoch [54/100], Step [30/75], Loss: 0.6519
# Epoch [54/100], Step [40/75], Loss: 0.5745
# Epoch [54/100], Step [50/75], Loss: 0.4961
# Epoch [54/100], Step [60/75], Loss: 0.5458
# Epoch [54/100], Step [70/75], Loss: 0.6495
# ====================================================================================================
# Epoch [54/100], Train - Loss: 0.5830, Acc: 69.38%, F1(macro): 69.23%, Current LR: 0.000437
# Epoch [54/100], Val   - Loss: 0.9930, Acc: 54.00%, F1(macro): 35.06%, Current LR: 0.000437
# ====================================================================================================
# No improvement in validation for 12 epochs, Best Val F1 is 58.94909688013137
# Epoch [55/100], Step [0/75], Loss: 0.5466
# Epoch [55/100], Step [10/75], Loss: 0.4830
# Epoch [55/100], Step [20/75], Loss: 0.5224
# Epoch [55/100], Step [30/75], Loss: 0.5628
# Epoch [55/100], Step [40/75], Loss: 0.5488
# Epoch [55/100], Step [50/75], Loss: 0.5785
# Epoch [55/100], Step [60/75], Loss: 0.5495
# Epoch [55/100], Step [70/75], Loss: 0.6090
# ====================================================================================================
# Epoch [55/100], Train - Loss: 0.5638, Acc: 69.38%, F1(macro): 69.36%, Current LR: 0.000422
# Epoch [55/100], Val   - Loss: 0.7918, Acc: 56.00%, F1(macro): 54.17%, Current LR: 0.000422
# ====================================================================================================
# No improvement in validation for 13 epochs, Best Val F1 is 58.94909688013137
# Epoch [56/100], Step [0/75], Loss: 0.6017
# Epoch [56/100], Step [10/75], Loss: 0.4728
# Epoch [56/100], Step [20/75], Loss: 0.5059
# Epoch [56/100], Step [30/75], Loss: 0.5810
# Epoch [56/100], Step [40/75], Loss: 0.6205
# Epoch [56/100], Step [50/75], Loss: 0.5637
# Epoch [56/100], Step [60/75], Loss: 0.5199
# Epoch [56/100], Step [70/75], Loss: 0.6927
# ====================================================================================================
# Epoch [56/100], Train - Loss: 0.5485, Acc: 70.46%, F1(macro): 70.39%, Current LR: 0.000406
# Epoch [56/100], Val   - Loss: 0.7231, Acc: 58.00%, F1(macro): 57.16%, Current LR: 0.000406
# ====================================================================================================
# No improvement in validation for 14 epochs, Best Val F1 is 58.94909688013137
# Epoch [57/100], Step [0/75], Loss: 0.6387
# Epoch [57/100], Step [10/75], Loss: 0.5328
# Epoch [57/100], Step [20/75], Loss: 0.7040
# Epoch [57/100], Step [30/75], Loss: 0.4505
# Epoch [57/100], Step [40/75], Loss: 0.5158
# Epoch [57/100], Step [50/75], Loss: 0.5853
# Epoch [57/100], Step [60/75], Loss: 0.4081
# Epoch [57/100], Step [70/75], Loss: 0.5834
# ====================================================================================================
# Epoch [57/100], Train - Loss: 0.5428, Acc: 71.58%, F1(macro): 71.54%, Current LR: 0.000391
# Epoch [57/100], Val   - Loss: 2.5928, Acc: 44.00%, F1(macro): 30.56%, Current LR: 0.000391
# ====================================================================================================
# No improvement in validation for 15 epochs, Best Val F1 is 58.94909688013137
# Epoch [58/100], Step [0/75], Loss: 0.4838
# Epoch [58/100], Step [10/75], Loss: 0.4165
# Epoch [58/100], Step [20/75], Loss: 0.5072
# Epoch [58/100], Step [30/75], Loss: 0.6321
# Epoch [58/100], Step [40/75], Loss: 0.5287
# Epoch [58/100], Step [50/75], Loss: 0.6145
# Epoch [58/100], Step [60/75], Loss: 0.6048
# Epoch [58/100], Step [70/75], Loss: 0.4509
# ====================================================================================================
# Epoch [58/100], Train - Loss: 0.5165, Acc: 73.25%, F1(macro): 73.21%, Current LR: 0.000376
# Epoch [58/100], Val   - Loss: 1.2157, Acc: 46.00%, F1(macro): 38.94%, Current LR: 0.000376
# ====================================================================================================
# No improvement in validation for 16 epochs, Best Val F1 is 58.94909688013137
# Epoch [59/100], Step [0/75], Loss: 0.4174
# Epoch [59/100], Step [10/75], Loss: 0.4897
# Epoch [59/100], Step [20/75], Loss: 0.4536
# Epoch [59/100], Step [30/75], Loss: 0.4672
# Epoch [59/100], Step [40/75], Loss: 0.4694
# Epoch [59/100], Step [50/75], Loss: 0.7024
# Epoch [59/100], Step [60/75], Loss: 0.5496
# Epoch [59/100], Step [70/75], Loss: 0.6661
# ====================================================================================================
# Epoch [59/100], Train - Loss: 0.4928, Acc: 74.29%, F1(macro): 74.22%, Current LR: 0.000361
# Epoch [59/100], Val   - Loss: 1.1526, Acc: 46.00%, F1(macro): 43.25%, Current LR: 0.000361
# ====================================================================================================
# No improvement in validation for 17 epochs, Best Val F1 is 58.94909688013137
# Epoch [60/100], Step [0/75], Loss: 0.4635
# Epoch [60/100], Step [10/75], Loss: 0.4822
# Epoch [60/100], Step [20/75], Loss: 0.4467
# Epoch [60/100], Step [30/75], Loss: 0.6220
# Epoch [60/100], Step [40/75], Loss: 0.3934
# Epoch [60/100], Step [50/75], Loss: 0.5108
# Epoch [60/100], Step [60/75], Loss: 0.4401
# Epoch [60/100], Step [70/75], Loss: 0.4920
# ====================================================================================================
# Epoch [60/100], Train - Loss: 0.4923, Acc: 74.17%, F1(macro): 74.17%, Current LR: 0.000345
# Epoch [60/100], Val   - Loss: 1.7843, Acc: 56.00%, F1(macro): 35.90%, Current LR: 0.000345
# ====================================================================================================
# No improvement in validation for 18 epochs, Best Val F1 is 58.94909688013137
# Epoch [61/100], Step [0/75], Loss: 0.3820
# Epoch [61/100], Step [10/75], Loss: 0.4553
# Epoch [61/100], Step [20/75], Loss: 0.4390
# Epoch [61/100], Step [30/75], Loss: 0.4117
# Epoch [61/100], Step [40/75], Loss: 0.3175
# Epoch [61/100], Step [50/75], Loss: 0.3429
# Epoch [61/100], Step [60/75], Loss: 0.4402
# Epoch [61/100], Step [70/75], Loss: 0.4352
# ====================================================================================================
# Epoch [61/100], Train - Loss: 0.4327, Acc: 79.12%, F1(macro): 79.09%, Current LR: 0.000331
# Epoch [61/100], Val   - Loss: 3.9888, Acc: 44.00%, F1(macro): 30.56%, Current LR: 0.000331
# ====================================================================================================
# ...
# Epoch [81/100], Step [30/75], Loss: 0.2621
# Epoch [81/100], Step [40/75], Loss: 0.1688
# Epoch [81/100], Step [50/75], Loss: 0.2465
# Epoch [81/100], Step [60/75], Loss: 0.3527
# Epoch [81/100], Step [70/75], Loss: 0.2258
# ====================================================================================================
# Epoch [81/100], Train - Loss: 0.1742, Acc: 92.12%, F1(macro): 92.12%, Current LR: 0.000086
# Epoch [81/100], Val   - Loss: 3.2574, Acc: 40.00%, F1(macro): 33.16%, Current LR: 0.000086
# ====================================================================================================
# No improvement in validation for 39 epochs, Best Val F1 is 58.94909688013137
# Epoch [82/100], Step [0/75], Loss: 0.2209
# Epoch [82/100], Step [10/75], Loss: 0.1010
# Epoch [82/100], Step [20/75], Loss: 0.2742
# Epoch [82/100], Step [30/75], Loss: 0.0816
# Epoch [82/100], Step [40/75], Loss: 0.1468
# Epoch [82/100], Step [50/75], Loss: 0.2434
# Epoch [82/100], Step [60/75], Loss: 0.1837
# Epoch [82/100], Step [70/75], Loss: 0.1147
# ====================================================================================================
# Epoch [82/100], Train - Loss: 0.1685, Acc: 92.04%, F1(macro): 92.04%, Current LR: 0.000078
# Epoch [82/100], Val   - Loss: 2.0397, Acc: 46.00%, F1(macro): 44.92%, Current LR: 0.000078
# ====================================================================================================
# No improvement in validation for 40 epochs, Best Val F1 is 58.94909688013137
# Epoch [83/100], Step [0/75], Loss: 0.0839
# Epoch [83/100], Step [10/75], Loss: 0.2768
# Epoch [83/100], Step [20/75], Loss: 0.1433
# Epoch [83/100], Step [30/75], Loss: 0.0738
# Epoch [83/100], Step [40/75], Loss: 0.1484
# Epoch [83/100], Step [50/75], Loss: 0.1266
# Epoch [83/100], Step [60/75], Loss: 0.1089
# Epoch [83/100], Step [70/75], Loss: 0.1946
# ====================================================================================================
# Epoch [83/100], Train - Loss: 0.1636, Acc: 92.17%, F1(macro): 92.16%, Current LR: 0.000070
# Epoch [83/100], Val   - Loss: 3.1637, Acc: 40.00%, F1(macro): 34.90%, Current LR: 0.000070
# ====================================================================================================
# No improvement in validation for 41 epochs, Best Val F1 is 58.94909688013137
# Epoch [84/100], Step [0/75], Loss: 0.0420
# Epoch [84/100], Step [10/75], Loss: 0.0911
# Epoch [84/100], Step [20/75], Loss: 0.1328
# Epoch [84/100], Step [30/75], Loss: 0.2191
# Epoch [84/100], Step [40/75], Loss: 0.2116
# Epoch [84/100], Step [50/75], Loss: 0.1341
# Epoch [84/100], Step [60/75], Loss: 0.0532
# Epoch [84/100], Step [70/75], Loss: 0.1436
# ====================================================================================================
# Epoch [84/100], Train - Loss: 0.1572, Acc: 92.67%, F1(macro): 92.66%, Current LR: 0.000062
# Epoch [84/100], Val   - Loss: 2.3527, Acc: 46.00%, F1(macro): 45.45%, Current LR: 0.000062
# ====================================================================================================
# No improvement in validation for 42 epochs, Best Val F1 is 58.94909688013137
# Epoch [85/100], Step [0/75], Loss: 0.2325
# Epoch [85/100], Step [10/75], Loss: 0.0641
# Epoch [85/100], Step [20/75], Loss: 0.1491
# Epoch [85/100], Step [30/75], Loss: 0.1695
# Epoch [85/100], Step [40/75], Loss: 0.1507
# Epoch [85/100], Step [50/75], Loss: 0.0742
# Epoch [85/100], Step [60/75], Loss: 0.1279
# Epoch [85/100], Step [70/75], Loss: 0.1923
# ====================================================================================================
# Epoch [85/100], Train - Loss: 0.1531, Acc: 93.25%, F1(macro): 93.25%, Current LR: 0.000054
# Epoch [85/100], Val   - Loss: 3.5852, Acc: 42.00%, F1(macro): 36.26%, Current LR: 0.000054
# ====================================================================================================
# No improvement in validation for 43 epochs, Best Val F1 is 58.94909688013137
# Epoch [86/100], Step [0/75], Loss: 0.0698
# Epoch [86/100], Step [10/75], Loss: 0.1021
# Epoch [86/100], Step [20/75], Loss: 0.0848
# Epoch [86/100], Step [30/75], Loss: 0.0748
# Epoch [86/100], Step [40/75], Loss: 0.1902
# Epoch [86/100], Step [50/75], Loss: 0.0696
# Epoch [86/100], Step [60/75], Loss: 0.2825
# Epoch [86/100], Step [70/75], Loss: 0.0693
# ====================================================================================================
# Epoch [86/100], Train - Loss: 0.1493, Acc: 93.38%, F1(macro): 93.37%, Current LR: 0.000048
# Epoch [86/100], Val   - Loss: 1.9989, Acc: 58.00%, F1(macro): 53.85%, Current LR: 0.000048
# ====================================================================================================
# No improvement in validation for 44 epochs, Best Val F1 is 58.94909688013137
# Epoch [87/100], Step [0/75], Loss: 0.1804
# Epoch [87/100], Step [10/75], Loss: 0.1656
# Epoch [87/100], Step [20/75], Loss: 0.1407
# Epoch [87/100], Step [30/75], Loss: 0.1129
# Epoch [87/100], Step [40/75], Loss: 0.1637
# Epoch [87/100], Step [50/75], Loss: 0.1328
# Epoch [87/100], Step [60/75], Loss: 0.1438
# Epoch [87/100], Step [70/75], Loss: 0.0932
# ====================================================================================================
# Epoch [87/100], Train - Loss: 0.1568, Acc: 93.08%, F1(macro): 93.08%, Current LR: 0.000041
# Epoch [87/100], Val   - Loss: 3.0454, Acc: 42.00%, F1(macro): 36.26%, Current LR: 0.000041
# ====================================================================================================
# No improvement in validation for 45 epochs, Best Val F1 is 58.94909688013137
# Epoch [88/100], Step [0/75], Loss: 0.0833
# Epoch [88/100], Step [10/75], Loss: 0.1507
# Epoch [88/100], Step [20/75], Loss: 0.0963
# Epoch [88/100], Step [30/75], Loss: 0.1901
# Epoch [88/100], Step [40/75], Loss: 0.1516
# Epoch [88/100], Step [50/75], Loss: 0.1326
# Epoch [88/100], Step [60/75], Loss: 0.0972
# Epoch [88/100], Step [70/75], Loss: 0.1303
# ====================================================================================================
# Epoch [88/100], Train - Loss: 0.1590, Acc: 92.42%, F1(macro): 92.41%, Current LR: 0.000035
# Epoch [88/100], Val   - Loss: 2.9262, Acc: 36.00%, F1(macro): 30.56%, Current LR: 0.000035
# ====================================================================================================
# No improvement in validation for 46 epochs, Best Val F1 is 58.94909688013137
# Epoch [89/100], Step [0/75], Loss: 0.0883
# Epoch [89/100], Step [10/75], Loss: 0.0746
# Epoch [89/100], Step [20/75], Loss: 0.0717
# Epoch [89/100], Step [30/75], Loss: 0.0711
# Epoch [89/100], Step [40/75], Loss: 0.0656
# Epoch [89/100], Step [50/75], Loss: 0.1023
# Epoch [89/100], Step [60/75], Loss: 0.1244
# Epoch [89/100], Step [70/75], Loss: 0.2963
# ====================================================================================================
# Epoch [89/100], Train - Loss: 0.1446, Acc: 93.04%, F1(macro): 93.04%, Current LR: 0.000030
# Epoch [89/100], Val   - Loss: 2.3195, Acc: 44.00%, F1(macro): 41.67%, Current LR: 0.000030
# ====================================================================================================
# No improvement in validation for 47 epochs, Best Val F1 is 58.94909688013137
# Epoch [90/100], Step [0/75], Loss: 0.0614
# Epoch [90/100], Step [10/75], Loss: 0.1701
# Epoch [90/100], Step [20/75], Loss: 0.1581
# Epoch [90/100], Step [30/75], Loss: 0.2015
# Epoch [90/100], Step [40/75], Loss: 0.0917
# Epoch [90/100], Step [50/75], Loss: 0.0950
# Epoch [90/100], Step [60/75], Loss: 0.1462
# Epoch [90/100], Step [70/75], Loss: 0.1516
# ====================================================================================================
# Epoch [90/100], Train - Loss: 0.1350, Acc: 93.58%, F1(macro): 93.58%, Current LR: 0.000024
# Epoch [90/100], Val   - Loss: 1.9530, Acc: 50.00%, F1(macro): 49.00%, Current LR: 0.000024
# ====================================================================================================
# No improvement in validation for 48 epochs, Best Val F1 is 58.94909688013137
# Epoch [91/100], Step [0/75], Loss: 0.0785
# Epoch [91/100], Step [10/75], Loss: 0.0805
# Epoch [91/100], Step [20/75], Loss: 0.0570
# Epoch [91/100], Step [30/75], Loss: 0.1327
# Epoch [91/100], Step [40/75], Loss: 0.2409
# Epoch [91/100], Step [50/75], Loss: 0.1539
# Epoch [91/100], Step [60/75], Loss: 0.0896
# Epoch [91/100], Step [70/75], Loss: 0.2879
# ====================================================================================================
# Epoch [91/100], Train - Loss: 0.1309, Acc: 93.62%, F1(macro): 93.62%, Current LR: 0.000020
# Epoch [91/100], Val   - Loss: 2.8435, Acc: 38.00%, F1(macro): 33.50%, Current LR: 0.000020
# ====================================================================================================
# No improvement in validation for 49 epochs, Best Val F1 is 58.94909688013137
# Epoch [92/100], Step [0/75], Loss: 0.1118
# Epoch [92/100], Step [10/75], Loss: 0.1340
# Epoch [92/100], Step [20/75], Loss: 0.0868
# Epoch [92/100], Step [30/75], Loss: 0.1074
# Epoch [92/100], Step [40/75], Loss: 0.0832
# Epoch [92/100], Step [50/75], Loss: 0.1559
# Epoch [92/100], Step [60/75], Loss: 0.2244
# Epoch [92/100], Step [70/75], Loss: 0.1045
# ====================================================================================================
# Epoch [92/100], Train - Loss: 0.1396, Acc: 93.92%, F1(macro): 93.91%, Current LR: 0.000016
# Epoch [92/100], Val   - Loss: 2.6026, Acc: 44.00%, F1(macro): 41.67%, Current LR: 0.000016
# ====================================================================================================
# No improvement in validation for 50 epochs, Best Val F1 is 58.94909688013137
# Epoch [93/100], Step [0/75], Loss: 0.2098
# Epoch [93/100], Step [10/75], Loss: 0.2509
# Epoch [93/100], Step [20/75], Loss: 0.1377
# Epoch [93/100], Step [30/75], Loss: 0.0826
# Epoch [93/100], Step [40/75], Loss: 0.1967
# Epoch [93/100], Step [50/75], Loss: 0.1459
# Epoch [93/100], Step [60/75], Loss: 0.1518
# Epoch [93/100], Step [70/75], Loss: 0.1301
# ====================================================================================================
# Epoch [93/100], Train - Loss: 0.1383, Acc: 93.79%, F1(macro): 93.79%, Current LR: 0.000012
# Epoch [93/100], Val   - Loss: 2.5413, Acc: 44.00%, F1(macro): 42.53%, Current LR: 0.000012
# ====================================================================================================
# No improvement in validation for 51 epochs, Best Val F1 is 58.94909688013137
# Epoch [94/100], Step [0/75], Loss: 0.1408
# Epoch [94/100], Step [10/75], Loss: 0.1093
# Epoch [94/100], Step [20/75], Loss: 0.0937
# Epoch [94/100], Step [30/75], Loss: 0.1607
# Epoch [94/100], Step [40/75], Loss: 0.1033
# Epoch [94/100], Step [50/75], Loss: 0.1954
# Epoch [94/100], Step [60/75], Loss: 0.1117
# Epoch [94/100], Step [70/75], Loss: 0.2221
# ====================================================================================================
# Epoch [94/100], Train - Loss: 0.1326, Acc: 94.08%, F1(macro): 94.08%, Current LR: 0.000009
# Epoch [94/100], Val   - Loss: 2.0385, Acc: 46.00%, F1(macro): 45.45%, Current LR: 0.000009
# ====================================================================================================
# No improvement in validation for 52 epochs, Best Val F1 is 58.94909688013137
# Epoch [95/100], Step [0/75], Loss: 0.0711
# Epoch [95/100], Step [10/75], Loss: 0.0962
# Epoch [95/100], Step [20/75], Loss: 0.0605
# Epoch [95/100], Step [30/75], Loss: 0.1866
# Epoch [95/100], Step [40/75], Loss: 0.1141
# Epoch [95/100], Step [50/75], Loss: 0.2338
# Epoch [95/100], Step [60/75], Loss: 0.2305
# Epoch [95/100], Step [70/75], Loss: 0.1459
# ====================================================================================================
# Epoch [95/100], Train - Loss: 0.1408, Acc: 93.71%, F1(macro): 93.71%, Current LR: 0.000006
# Epoch [95/100], Val   - Loss: 2.4040, Acc: 44.00%, F1(macro): 41.67%, Current LR: 0.000006
# ====================================================================================================
# No improvement in validation for 53 epochs, Best Val F1 is 58.94909688013137
# Epoch [96/100], Step [0/75], Loss: 0.2067
# Epoch [96/100], Step [10/75], Loss: 0.0688
# Epoch [96/100], Step [20/75], Loss: 0.1256
# Epoch [96/100], Step [30/75], Loss: 0.1398
# Epoch [96/100], Step [40/75], Loss: 0.1527
# Epoch [96/100], Step [50/75], Loss: 0.1884
# Epoch [96/100], Step [60/75], Loss: 0.2805
# Epoch [96/100], Step [70/75], Loss: 0.2041
# ====================================================================================================
# Epoch [96/100], Train - Loss: 0.1266, Acc: 94.08%, F1(macro): 94.08%, Current LR: 0.000004
# Epoch [96/100], Val   - Loss: 2.3309, Acc: 46.00%, F1(macro): 44.92%, Current LR: 0.000004
# ====================================================================================================
# No improvement in validation for 54 epochs, Best Val F1 is 58.94909688013137
# Epoch [97/100], Step [0/75], Loss: 0.0941
# Epoch [97/100], Step [10/75], Loss: 0.1489
# Epoch [97/100], Step [20/75], Loss: 0.2091
# Epoch [97/100], Step [30/75], Loss: 0.1027
# Epoch [97/100], Step [40/75], Loss: 0.1680
# Epoch [97/100], Step [50/75], Loss: 0.1040
# Epoch [97/100], Step [60/75], Loss: 0.1385
# Epoch [97/100], Step [70/75], Loss: 0.1691
# ====================================================================================================
# Epoch [97/100], Train - Loss: 0.1288, Acc: 93.83%, F1(macro): 93.83%, Current LR: 0.000002
# Epoch [97/100], Val   - Loss: 2.1365, Acc: 44.00%, F1(macro): 43.64%, Current LR: 0.000002
# ====================================================================================================
# No improvement in validation for 55 epochs, Best Val F1 is 58.94909688013137
# Epoch [98/100], Step [0/75], Loss: 0.1573
# Epoch [98/100], Step [10/75], Loss: 0.2926
# Epoch [98/100], Step [20/75], Loss: 0.0707
# Epoch [98/100], Step [30/75], Loss: 0.2127
# Epoch [98/100], Step [40/75], Loss: 0.0636
# Epoch [98/100], Step [50/75], Loss: 0.1605
# Epoch [98/100], Step [60/75], Loss: 0.0568
# Epoch [98/100], Step [70/75], Loss: 0.1891
# ====================================================================================================
# Epoch [98/100], Train - Loss: 0.1367, Acc: 93.29%, F1(macro): 93.29%, Current LR: 0.000001
# Epoch [98/100], Val   - Loss: 2.1881, Acc: 46.00%, F1(macro): 44.92%, Current LR: 0.000001
# ====================================================================================================
# No improvement in validation for 56 epochs, Best Val F1 is 58.94909688013137
# Epoch [99/100], Step [0/75], Loss: 0.2153
# Epoch [99/100], Step [10/75], Loss: 0.2562
# Epoch [99/100], Step [20/75], Loss: 0.0709
# Epoch [99/100], Step [30/75], Loss: 0.1320
# Epoch [99/100], Step [40/75], Loss: 0.1377
# Epoch [99/100], Step [50/75], Loss: 0.1285
# Epoch [99/100], Step [60/75], Loss: 0.1120
# Epoch [99/100], Step [70/75], Loss: 0.1992
# ====================================================================================================
# Epoch [99/100], Train - Loss: 0.1315, Acc: 94.12%, F1(macro): 94.12%, Current LR: 0.000000
# Epoch [99/100], Val   - Loss: 2.1604, Acc: 48.00%, F1(macro): 47.24%, Current LR: 0.000000
# ====================================================================================================
# No improvement in validation for 57 epochs, Best Val F1 is 58.94909688013137
# Epoch [100/100], Step [0/75], Loss: 0.2125
# Epoch [100/100], Step [10/75], Loss: 0.0622
# Epoch [100/100], Step [20/75], Loss: 0.2201
# Epoch [100/100], Step [30/75], Loss: 0.1398
# Epoch [100/100], Step [40/75], Loss: 0.1011
# Epoch [100/100], Step [50/75], Loss: 0.1463
# Epoch [100/100], Step [60/75], Loss: 0.1019
# Epoch [100/100], Step [70/75], Loss: 0.0831
# ====================================================================================================
# Epoch [100/100], Train - Loss: 0.1316, Acc: 93.83%, F1(macro): 93.83%, Current LR: 0.000000
# Epoch [100/100], Val   - Loss: 2.1133, Acc: 46.00%, F1(macro): 45.45%, Current LR: 0.000000
# ====================================================================================================
# No improvement in validation for 58 epochs, Best Val F1 is 58.94909688013137
